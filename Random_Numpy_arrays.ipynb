# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # rand()

# %%
import numpy as np

# %% [markdown]
# arr=np.random.rand(5)
# print(arr)

# %%
arr=np.random.rand(5,5)
print(arr)
# Out:
# [[0.62639676 0.32582726 0.11909729 0.16940268 0.84644536]
#  [0.04401157 0.24687807 0.97897427 0.36960379 0.03294166]
#  [0.96180159 0.31036406 0.73414579 0.47034735 0.96969187]
#  [0.4761883  0.23486194 0.10157721 0.9513874  0.05351767]
#  [0.3031333  0.95082817 0.46039627 0.00847511 0.09616539]]

# %%
arr=np.random.rand(2,2)
print(arr)
# Out:
# [[0.13556605 0.36908234]
#  [0.32113399 0.66098077]]

# %% [markdown]
# # randn() function

# %%
arr=np.random.randn(5)
print(arr)
# Out:
# [-0.89994672 -0.44151195 -0.02022838 -0.52691741  1.3400071 ]

# %%
arr=np.random.randn(5,5)
print(arr)
# Out:
# [[-0.36776016  0.15642235  1.39508982 -0.62762958 -0.88023023]
#  [ 0.74430666 -2.47932944 -0.31864691  0.72180576 -0.37915293]
#  [ 0.03862168 -0.86479229  0.28402847 -0.40761344  0.97140156]
#  [-0.57164002  1.92525453 -0.24239021  0.4320327  -0.35380928]
#  [ 0.08865544 -0.10106387 -0.42664536 -0.01644593 -1.18845841]]

# %%
arr=np.random.randn(3,3)
print(arr)
# Out:
# [[-0.98715293 -0.09615855 -0.64295047]
#  [-0.13180186 -0.30344218 -0.34814746]
#  [-1.57537175  1.30960877 -0.41587139]]

# %% [markdown]
# # randf() function

# %%
arr=np.random.ranf(5)
print(arr)
# Out:
# [0.3698639  0.14406059 0.83750241 0.92895999 0.60738258]

# %% [markdown]
# # randint() function

# %%
arr=np.random.randint(5,20,5)
print(arr)
# Out:
# [10 13 19  8 15]
